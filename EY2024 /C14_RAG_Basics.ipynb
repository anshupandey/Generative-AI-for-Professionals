# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/Generative-AI-for-Professionals/blob/main/EY2024%20/C14_RAG_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring Embeddeings from Azure OpenAI

# %%
api_key = "xxxxxxxxx"
api_version = "2023-07-01-preview" # "2023-05-15"
azure_endpoint = "https://xxxxxxxx.openai.azure.com/"
embedding_model_name = "text-embedding-ada-002"

# %%
import os
os.environ["OPENAI_API_VERSION"] = api_version
os.environ["AZURE_OPENAI_ENDPOINT"] = azure_endpoint
os.environ["AZURE_OPENAI_API_KEY"] = api_key
os.environ["AZURE_OPENAI_API_VERSION"] = api_version

# %%
from langchain_openai import AzureOpenAIEmbeddings

embeddings = AzureOpenAIEmbeddings(azure_deployment=embedding_model_name)

# %%
v1,v2,v3 = embeddings.embed_documents(["I like python programming, its a good programming language.",
                                    "Python is an amazing programming language, i like it a lot.",
                                    "Hello World, how are you?"])

# %%
print(v1)
# Out:
# [-0.0013156682213057065, 0.0026297250217315626, -0.013612694997111383, -0.031015287990858433, -0.005349685887444464, -0.007979410676345383, 0.0002717140879173163, -0.04545299322555038, -0.0036352081114280235, -0.03145357584372632, 0.005017747621695131, 0.005958776437334645, 0.008379026290742008, 0.0006618624882294972, -0.0010626860862094016, 0.014734194569391004, 0.02266204350287146, -0.01945223094594995, 0.007676477055110787, 0.019258869753593616, -0.011982006915895594, 0.02315189309860428, 0.0035610860105839033, -0.019413558707478684, -0.012691001369384931, 0.018369402680819026, -0.0185369830017429, -0.02174679555866441, -0.0007843251782010057, -0.007296198025611083, 0.02549802131682881, -0.013818947556506525, -0.01669359760893514, 0.0025991094219982615, -0.02758633150750298, -0.00011037755724157664, -0.01350956778609124, -0.019310431496458544, 0.004966184481846345, 0.005987781081849382, 0.021153818751911448, 0.02406714104281133, -0.008140546245072428, -0.02233977236541737, -0.02203039259500209, 0.013818947556506525, 0.006961036918102048, -0.021347179944267786, -0.00559461115097216, 0.018691673818273115, 0.003899469727021996, 0.021759686925703212, -0.020135443596684253, -0.02026435167913686, 0.014695522330919737, 0.006393841448442836, -0.005617170111967495, -0.003190475273532659, 0.004647136651813244, -0.01370292990977015, 0.0197873915877977, 0.008662624258402257, -0.006000671517565614, -0.005423807988288585, 0.0051208739013927015, 0.004863057736487488, 0.022649152135832656, 0.025343330500298595, 0.030602781009423007, 0.005201441685756224, 0.012362286411056585, 0.004927511777713792, -0.02469879008803556, 0.020767094504553628, 0.03029340123900772, 0.009481190675108567, -0.0030615671910800522, 0.01702875825078289, 0.0005825034441488451, -0.00022115794059928554, -0.005984558240089681, -0.03529503558322692, -0.004096054459629964, -0.0018321062615560587, 0.0060844621436888366, 0.001836940291364967, -0.023886669354848653, 0.01504357433980629, -0.007734485412817688, -0.01109898645796298, 0.0016532463437191954, 0.008469262134723347, 0.003396728298589087, 0.015713896554824358, -0.017918225323557475, 0.00583309119664174, -0.00675478389304562, -0.010196629880794734, -0.0066452123954899335, -0.019349105597574953, -0.011150550063473052, 0.007702258392204537, -0.01104097810025608, -0.009481190675108567, -0.03145357584372632, -0.012865027373828207, 0.011066759903011114, 0.00014320883158084187, 0.03266531219130986, 0.013870511162016597, -0.015933040481258303, 0.040760740514391616, 0.0047760447342658505, -0.043751407282234034, -0.0043957661704274315, -0.012987490704083983, 0.0013132512064012523, -0.012317168489065914, -0.012852136938111975, -0.0005692098039666862, 0.011182776618424917, 0.017479937470689585, 0.015842804637276966, -0.008623951088608417, 0.038208357874126804, 0.017015868746389228, -0.0022188306253292, -0.04166309522891472, 0.010899179582087241, 0.0009313609888523406, 0.020625295055062217, 0.013818947556506525, 0.013561131391601313, 0.0007533066650400812, -0.019361995101968614, 0.014618177853977201, -0.015391626348692842, -0.005095092564298952, -0.03042230932146033, 0.004711590693039547, 0.02005809911974172, 0.033361416209082964, -0.0018627219777046812, -0.0020721976116901673, -0.007908511882922251, 0.02440230168465908, 0.014025200115901667, -0.016422890076991124, -0.0012931092603103718, 0.009294273303626487, 0.015636552077881824, -0.01909128943266974, 0.01124078590745439, 0.021592104742134195, -0.006954591700243932, -0.016526017288011265, 0.020483495605570806, 0.00496940685794476, 0.021759686925703212, -0.004128281480243115, 0.004421547507521182, -0.0037222211136496617, -0.0006948951610749135, -0.020070990486780522, -0.008069646520326722, 0.031814515494361394, 0.03261374672315464, -0.003796343214493782, -0.01504357433980629, 0.01412832732692181, 0.01833073044234776, 0.021733904191625606, -0.03379970033666056, 0.009094465496428174, 0.017853770351008602, 0.020380370257195808, 0.0015477028162865273, 0.0017612067696409963, -0.01671 ...

# %%
len(v1), len(v2), len(v3)
# Out:
# (1536, 1536, 1536)

# %%
from numpy.linalg import norm
import numpy as np
# cosine similarity
np.dot(v1,v2)/(norm(v1),norm(v2))
# Out:
# array([0.95151839, 0.95151839])

# %%
from numpy.linalg import norm
import numpy as np

np.dot(v1,v3)/(norm(v1),norm(v3))
# Out:
# array([0.76263389, 0.76263389])

# %%
from numpy.linalg import norm
import numpy as np

np.dot(v2,v3)/(norm(v2),norm(v3))
# Out:
# array([0.76539893, 0.76539893])
